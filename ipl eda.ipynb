# %%
# dataset link = https://raw.githubusercontent.com/12345k/IPL-Dataset/master/IPL/data.csv

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
ipl.head(2)
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
#
#    result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Kolkata Knight Riders          140               0
# 1  normal           0    Chennai Super Kings           33               0
#
#   player_of_match                                       venue    umpire1  \
# 0     BB McCullum                       M Chinnaswamy Stadium  Asad Rauf
# 1      MEK Hussey  Punjab Cricket Association Stadium, Mohali  MR Benson
#
#        umpire2  umpire3
# 0  RE Koertzen      NaN
# 1   SL Shastri      NaN

# %%
ipl.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  577.000000   577.000000  577.000000   577.000000      577.000000
# mean   289.000000  2012.029463    0.025997    13.715771        3.363951
# std    166.709828     2.486247    0.159263    23.619282        3.416049
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    145.000000  2010.000000    0.000000     0.000000        0.000000
# 50%    289.000000  2012.000000    0.000000     0.000000        3.000000
# 75%    433.000000  2014.000000    0.000000    20.000000        6.000000
# max    577.000000  2016.000000    1.000000   144.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
ipl["umpire3"].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: umpire3, dtype: float64

# %%
ipl["umpire3"].drop
# Out:
# <bound method Series.drop of 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 572   NaN
# 573   NaN
# 574   NaN
# 575   NaN
# 576   NaN
# Name: umpire3, Length: 577, dtype: float64>

# %%
ipl["city"].describe()
# Out:
# count        570
# unique        30
# top       Mumbai
# freq          77
# Name: city, dtype: object

# %%
ipl["city"].mode()
# Out:
# 0    Mumbai
# dtype: object

# %%
a=list[ipl["city"].value_counts()]

# %%
a
# Out:
# list[Mumbai            77
# Bangalore         58
# Kolkata           54
# Delhi             53
# Chennai           48
# Chandigarh        42
# Hyderabad         41
# Jaipur            33
# Pune              25
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Dharamsala         9
# Johannesburg       8
# Cuttack            7
# Port Elizabeth     7
# Cape Town          7
# Ranchi             7
# Abu Dhabi          7
# Sharjah            6
# Raipur             6
# Kochi              5
# Rajkot             5
# Kimberley          3
# Nagpur             3
# East London        3
# Bloemfontein       2
# Indore             2
# Kanpur             2
# Name: city, dtype: int64]

# %%
type(a)
# Out:
# types.GenericAlias

# %%
ipl.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
ipl["venue"].describe()
# Out:
# count                       577
# unique                       35
# top       M Chinnaswamy Stadium
# freq                         58
# Name: venue, dtype: object

# %%
ipl["venue"].max()
# Out:
# 'Wankhede Stadium'

# %% [markdown]
# # Analysis acc to video strts here

# %%
ipl.shape
# Out:
# (577, 18)

# %%
p_of_the_match=ipl["player_of_match"].value_counts()

# %%
p_of_the_match
# Out:
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# RG Sharma         13
#                   ..
# MN Samuels         1
# S Badrinath        1
# R Bhatia           1
# RE Levi            1
# BCJ Cutting        1
# Name: player_of_match, Length: 187, dtype: int64

# %%
p_of_the_match[0:10]
# Out:
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# RG Sharma         13
# SK Raina          13
# AM Rahane         12
# MEK Hussey        12
# G Gambhir         12
# MS Dhoni          12
# Name: player_of_match, dtype: int64

# %%
ipl["player_of_match"]
# Out:
# 0         BB McCullum
# 1          MEK Hussey
# 2         MF Maharoof
# 3          MV Boucher
# 4           DJ Hussey
#             ...
# 572           V Kohli
# 573    AB de Villiers
# 574      MC Henriques
# 575         DA Warner
# 576       BCJ Cutting
# Name: player_of_match, Length: 577, dtype: object

# %%
ipl["player_of_match"].value_counts()
# Out:
# CH Gayle          17
# YK Pathan         16
# AB de Villiers    15
# DA Warner         14
# RG Sharma         13
#                   ..
# MN Samuels         1
# S Badrinath        1
# R Bhatia           1
# RE Levi            1
# BCJ Cutting        1
# Name: player_of_match, Length: 187, dtype: int64

# %%
ipl["player_of_match"].value_counts()[0:2]
# Out:
# CH Gayle     17
# YK Pathan    16
# Name: player_of_match, dtype: int64

# %%
a=list(ipl["player_of_match"].value_counts()[0:5].keys())

# %%
b=list(ipl["player_of_match"].value_counts()[0:5])

# %%
a
# Out:
# ['CH Gayle', 'YK Pathan', 'AB de Villiers', 'DA Warner', 'RG Sharma']

# %%
b
# Out:
# [17, 16, 15, 14, 13]

# %%
plt.bar(a,b)
plt.title("man of the match")
plt.grid(True)
plt.show()

# %%
ipl["result"].value_counts()
# Out:
# normal       568
# tie            6
# no result      3
# Name: result, dtype: int64

# %%
#toss winner

# %%
ipl["toss_winner"].value_counts()
# Out:
# Mumbai Indians                 74
# Kolkata Knight Riders          69
# Chennai Super Kings            66
# Kings XI Punjab                64
# Delhi Daredevils               64
# Rajasthan Royals               63
# Royal Challengers Bangalore    61
# Deccan Chargers                43
# Sunrisers Hyderabad            30
# Pune Warriors                  20
# Kochi Tuskers Kerala            8
# Gujarat Lions                   8
# Rising Pune Supergiants         7
# Name: toss_winner, dtype: int64

# %%
a=ipl[ipl["win_by_runs"]!=0]

# %%
a
# Out:
#       id  season           city        date                        team1  \
# 0      1    2008      Bangalore  2008-04-18        Kolkata Knight Riders
# 1      2    2008     Chandigarh  2008-04-19          Chennai Super Kings
# 7      8    2008        Chennai  2008-04-23          Chennai Super Kings
# 9     10    2008     Chandigarh  2008-04-25              Kings XI Punjab
# 14    15    2008      Bangalore  2008-04-28          Chennai Super Kings
# ..   ...     ...            ...         ...                          ...
# 565  566    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 566  567    2016      Bangalore  2016-05-18  Royal Challengers Bangalore
# 571  572    2016        Kolkata  2016-05-22        Kolkata Knight Riders
# 574  575    2016          Delhi  2016-05-25          Sunrisers Hyderabad
# 576  577    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
a.shape
# Out:
# (261, 18)

# %%
ipl.shape
# Out:
# (577, 18)

# %%
261/577
# Out:
# 0.45233968804159447

# %%
ipl.head(1)
# Out:
#    id  season       city        date                  team1  \
# 0   1    2008  Bangalore  2008-04-18  Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Kolkata Knight Riders          140               0
#
#   player_of_match                  venue    umpire1      umpire2  umpire3
# 0     BB McCullum  M Chinnaswamy Stadium  Asad Rauf  RE Koertzen      NaN

# %%
plt.hist(a["win_by_runs"],)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#phle batting karte hue jitna
a["winner"].value_counts()
# Out:
# Chennai Super Kings            46
# Mumbai Indians                 43
# Kolkata Knight Riders          29
# Kings XI Punjab                28
# Royal Challengers Bangalore    27
# Rajasthan Royals               23
# Delhi Daredevils               18
# Deccan Chargers                18
# Sunrisers Hyderabad            18
# Pune Warriors                   6
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
ipl.head(1)
# Out:
#    id  season       city        date                  team1  \
# 0   1    2008  Bangalore  2008-04-18  Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Kolkata Knight Riders          140               0
#
#   player_of_match                  venue    umpire1      umpire2  umpire3
# 0     BB McCullum  M Chinnaswamy Stadium  Asad Rauf  RE Koertzen      NaN

# %%
for i in ipl["win_by_runs"]:
    if i==0:
        pass
    else:
        print(i)
# Out:
# 140
# 33
# 6
# 66
# 13
# 10
# 45
# 9
# 29
# 5
# 18
# 23
# 23
# 41
# 12
# 6
# 65
# 25
# 3
# 1
# 14
# 10
# 3
# 105
# 19
# 75
# 92
# 11
# 24
# 9
# 12
# 27
# 92
# 3
# 38
# 9
# 8
# 18
# 78
# 78
# 19
# 12
# 16
# 53
# 12
# 2
# 1
# 14
# 24
# 12
# 6
# 11
# 4
# 31
# 55
# 98
# 6
# 34
# 10
# 36
# 31
# 39
# 17
# 17
# 41
# 40
# 67
# 24
# 23
# 63
# 37
# 2
# 24
# 14
# 37
# 13
# 39
# 57
# 11
# 35
# 38
# 22
# 2
# 9
# 33
# 21
# 16
# 6
# 48
# 8
# 29
# 37
# 25
# 55
# 17
# 26
# 38
# 19
# 23
# 20
# 21
# 17
# 85
# 10
# 32
# 63
# 76
# 18
# 10
# 29
# 111
# 11
# 82
# 43
# 58
# 28
# 31
# 20
# 74
# 22
# 22
# 42
# 27
# 2
# 59
# 13
# 20
# 46
# 18
# 37
# 7
# 47
# 1
# 13
# 1
# 10
# 7
# 43
# 25
# 35
# 27
# 45
# 32
# 21
# 34
# 9
# 18
# 38
# 86
# 2
# 22
# 5
# 9
# 19
# 44
# 41
# 48
# 24
# 4
# 11
# 87
# 86
# 130
# 7
# 58
# 14
# 15
# 4
# 37
# 15
# 17
# 60
# 65
# 77
# 46
# 4
# 30
# 7
# 33
# 14
# 23
# 50
# 38
# 24
# 48
# 23
# 41
# 93
# 72
# 7
# 2
# 4
# 23
# 15
# 34
# 10
# 19
# 44
# 32
# 32
# 16
# 62
# 25
# 30
# 15
# 16
# ...

# %%
ipl.head(1)
# Out:
#    id  season       city        date                  team1  \
# 0   1    2008  Bangalore  2008-04-18  Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Kolkata Knight Riders          140               0
#
#   player_of_match                  venue    umpire1      umpire2  umpire3
# 0     BB McCullum  M Chinnaswamy Stadium  Asad Rauf  RE Koertzen      NaN

# %%
batting_winner=ipl[ipl["win_by_runs"]!=0]

# %%
batting_winner
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
ipl.shape
# Out:
# (577, 18)

# %%
batting_winner.shape
# Out:
# (0, 18)

# %%
ipl.head(2)
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
#
#    result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Kolkata Knight Riders            0               0
# 1  normal           0    Chennai Super Kings            0               0
#
#   player_of_match                                       venue    umpire1  \
# 0     BB McCullum                       M Chinnaswamy Stadium  Asad Rauf
# 1      MEK Hussey  Punjab Cricket Association Stadium, Mohali  MR Benson
#
#        umpire2  umpire3
# 0  RE Koertzen      NaN
# 1   SL Shastri      NaN

# %%
ipl[ipl["win_by_runs"]!=0]
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
ipl["win_by_runs"].describe()
# Out:
# count    577.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0
# Name: win_by_runs, dtype: float64

# %%
ipl["win_by_runs"].value_counts()
# Out:
# 0    577
# Name: win_by_runs, dtype: int64

# %%
ipl=pd.read_csv("https://raw.githubusercontent.com/12345k/IPL-Dataset/master/IPL/data.csv")

# %%
ipl.head(1)
# Out:
#    id  season       city        date                  team1  \
# 0   1    2008  Bangalore  2008-04-18  Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Kolkata Knight Riders          140               0
#
#   player_of_match                  venue    umpire1      umpire2  umpire3
# 0     BB McCullum  M Chinnaswamy Stadium  Asad Rauf  RE Koertzen      NaN

# %%
ipl["win_by_runs"].value_counts()
# Out:
# 0      316
# 23       9
# 10       8
# 24       8
# 9        8
#       ...
# 53       1
# 75       1
# 105      1
# 66       1
# 80       1
# Name: win_by_runs, Length: 83, dtype: int64

# %%
a=ipl[ipl["win_by_runs"]!=0]

# %%
a.shape
# Out:
# (261, 18)

# %%
a["winner"].describe()
# Out:
# count                     261
# unique                     13
# top       Chennai Super Kings
# freq                       46
# Name: winner, dtype: object

# %%
b=a["winner"].value_counts()

# %%
b
# Out:
# Chennai Super Kings            46
# Mumbai Indians                 43
# Kolkata Knight Riders          29
# Kings XI Punjab                28
# Royal Challengers Bangalore    27
# Rajasthan Royals               23
# Delhi Daredevils               18
# Deccan Chargers                18
# Sunrisers Hyderabad            18
# Pune Warriors                   6
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
namesofteam=list(b.keys())

# %%
namesofteam
# Out:
# ['Chennai Super Kings',
#  'Mumbai Indians',
#  'Kolkata Knight Riders',
#  'Kings XI Punjab',
#  'Royal Challengers Bangalore',
#  'Rajasthan Royals',
#  'Delhi Daredevils',
#  'Deccan Chargers',
#  'Sunrisers Hyderabad',
#  'Pune Warriors',
#  'Kochi Tuskers Kerala',
#  'Rising Pune Supergiants',
#  'Gujarat Lions']

# %%
values=list(b.values)

# %%
plt.figure(figsize=(20,20))
plt.bar(namesofteam,values)
# Out:
# <BarContainer object of 13 artists>

# %%
ipl.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
ipl["city"].value_counts()
# Out:
# Mumbai            77
# Bangalore         58
# Kolkata           54
# Delhi             53
# Chennai           48
# Chandigarh        42
# Hyderabad         41
# Jaipur            33
# Pune              25
# Durban            15
# Centurion         12
# Ahmedabad         12
# Visakhapatnam     11
# Dharamsala         9
# Johannesburg       8
# Cuttack            7
# Port Elizabeth     7
# Cape Town          7
# Ranchi             7
# Abu Dhabi          7
# Sharjah            6
# Raipur             6
# Kochi              5
# Rajkot             5
# Kimberley          3
# Nagpur             3
# East London        3
# Bloemfontein       2
# Indore             2
# Kanpur             2
# Name: city, dtype: int64

# %%
ipl.head(1)
# Out:
#    id  season       city        date                  team1  \
# 0   1    2008  Bangalore  2008-04-18  Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Kolkata Knight Riders          140               0
#
#   player_of_match                  venue    umpire1      umpire2  umpire3
# 0     BB McCullum  M Chinnaswamy Stadium  Asad Rauf  RE Koertzen      NaN

# %%
import numpy as np

# %%
np.sum(ipl["toss_winner"]==ipl["winner"])
# Out:
# 291

# %%
ipl.shape
# Out:
# (577, 18)
